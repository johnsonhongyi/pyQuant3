# %% [markdown]
# # Tentcent VIP check

# %% [markdown]
# ## load vip

# %%
import io
r_root ='/Users/Johnson/Downloads/iyanshu/feichi/'
res_disk=['disk1','disk2','disk3','disk4','disk5']
res_disk=['vip2']
def get_file_list(f_path,encoding='utf8',sep=None):
    fout = io.open(f_path, 'rU',encoding=encoding).readlines()
    f_list =[]
    if not sep:
        for m in fout:
            count_list = m.split('.')
            if len(count_list) <2:
                f_list.append(m.strip())
            else:
                f_list.append(m.split('.')[:-1][0].strip())
    else:
        for m in fout:
#             print m.split(sep)[0]
            f_list.append(m.split(sep)[0].strip()+';'+m.split(sep)[1].strip())
    return f_list
local_list=[]
for f in res_disk:
    f_p = r_root+f+'.csv'
    data_list = get_file_list(f_p,encoding='utf8',sep=';')
    local_list.extend(data_list)
print "locallist:%s %s"%(len(local_list),local_list[0])
# Out:
# locallist:701 ﻿捉迷藏;2016年

# %% [markdown]
# ## check vip

# %%
#### -*- coding:utf-8 -*-
import urllib2
import json
from bs4 import BeautifulSoup
from urllib2 import quote, unquote
import time

root_url ='https://v.qq.com/x/search/?q=%s&stag=0&smartbox_ab='
# search_url = root_url%('国产凌凌漆')

def search_tencent_VIP(title,year=None):
    print "Sh:%s year:%s"%(title.strip(),year)
    search_url = root_url%(title.strip())
    # print search_url
    # print urllib2.quote("http://192.168.10.105:8080/media/activities/上海/ad/1515043837.jpg")
    # help(quote)?
    search_url = quote(search_url, safe=";/?:@&=+$,")
    # print "quote_url:%s"%(search_url)
    html = urllib2.urlopen(search_url)
    html_data = html.read()
    soup = BeautifulSoup(html_data, 'html.parser')
    # print soup
#     content = soup.find("div", {"class":"_infos"}).find_all("span",{"class":"mark_v"})
    content = soup.find_all("div", {"class":"_infos"})
#     _playlist = soup.find("div", {"class":"_playlist"}).find_all("i",{"class":"icon_sm icon_play_sm"})
#     content_playlist = soup.find_all("div", {"class":"_playlist"})
    content_playsrc = soup.find_all("div", {"class":"_playsrc"})
    
#     ("span",{"class":"icon_text"})
    
#     print len(content),len(content_playlist)
    # content_Vip = soup.find("div", {"class":"_infos"}).find_all("span",{"class":"mark_v"})
    # .find_all("span",{"class":"_infos"})

    # if content:
    #     print "VIP"
    # else:
    #     print "Free"
    find_ok = 0
    for idx, con in enumerate(content):
        type_l = con.find("span", {"class":"type"}).get_text()
        if type_l==u'电影':
    #         print con.find("em", {"class":"hl"}).find("span", {"class":"sub"})
    #         print con.find("div", {"class":"_infos"}).find("em", {"class":"hl"})
#             print con.find("em", {"class":"hl"}) ,con.find("span", {"class":"sub"})
            tt_S = con.find("em", {"class":"hl"})
            tt_O = con.find("span", {"class":"sub"})
#             print con
#             print content_playlist[idx].find("span",{"class":"icon_text"}).get_text()
#             print len(content_playsrc),idx
            src_idx = idx if len(content_playsrc) > idx else 0
#             print src_idx
            playsrc = content_playsrc[src_idx].find("span",{"class":"icon_text"})
            if playsrc is not None:
                playsrc = playsrc.get_text().strip()
                
#             print tt_S,tt_O
        
            if tt_S and tt_O:
                if title.decode('utf8') == (tt_S.get_text().strip()):
                    if year:
                        if tt_O.get_text().find(year) > 0:
                            find_ok +=1
                            print "ST:%s  TT:%s Year:%s"%(title.decode('utf8'),tt_S.get_text().strip() ,tt_O.get_text().strip()),
                            Vip_s =  con.find("span", {"class":"mark_v"})
                            if playsrc:
                                if playsrc == (u'腾讯视频') :
                                    print "idx: %s type:%s    : %s %s"%(idx,type_l,'VIP' if (Vip_s) is not None else u'免费',playsrc )
                                else:
                                    print "\t\t : No %s"%(playsrc)
                            break
                            
                    else:
                            find_ok +=1
                            print "ST:%s  TT:%s Year:%s"%(title.decode('utf8'),tt_S.get_text().strip() ,tt_O.get_text().strip()),
                            Vip_s =  con.find("span", {"class":"mark_v"}) 
                            if playsrc:
                                if playsrc == (u'腾讯视频') :
                                    print "idx: %s type:%s    : %s %s"%(idx,type_l,'VIP' if (Vip_s) is not None else u'免费',playsrc )
                                else:
                                    print "\t\t : No %s"%(playsrc)
#                 else:
#                     tt_S , tt_O
#             else:
#                 print tt_S , tt_O
    if year:
        if find_ok == 0:
            search_tencent_VIP(title)
        
    
    
    #     print "con:%s %s"%(idx,con)
    # print content

# local_list=[u'火海凌云;2016年',u'阿尔及尔之战;1966年']    
    
for title in local_list[445:]:
    search_tencent_VIP(title.split(';')[0].encode('utf8'),title.split(';')[1].replace(u'年','').encode('utf8'))
#     search_tencent_VIP(title.split(';')[0].encode('utf8'))
#     break
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9eeab77e62d4> in <module>()
#      95 # local_list=[u'火海凌云;2016年',u'阿尔及尔之战;1966年']
#      96
# ---> 97 for title in local_list[445:]:
#      98     search_tencent_VIP(title.split(';')[0].encode('utf8'),title.split(';')[1].replace(u'年','').encode('utf8'))
#      99 #     search_tencent_VIP(title.split(';')[0].encode('utf8'))
#
# NameError: name 'local_list' is not defined

# %%
print u'\u7231\u5947\u827a\u4ed8\u8d39',u'\u666e\u901a\u8bdd\u7248',u'\u4e0b\u8f7d\u5ba2\u6237\u7aef\uff0c'
# Out:
# 爱奇艺付费 普通话版 下载客户端，

# %% [markdown]
# # Top250

# %%
# -*- coding: UTF-8 -*-
"""
 获取豆瓣电影评分排行榜
"""
import urllib2
import requests
from bs4 import BeautifulSoup


# 获得指定开始排行的电影url
def get_url(root_url,start):
    return root_url+"?start="+str(start)+"&filter="

def get_review(page_url):
    movies_list=[]
    response=requests.get(page_url)
    soup=BeautifulSoup(response.text,"lxml")
    soup=soup.find('ol','grid_view')
    for tag_li in soup.find_all('li'):
        dict={}
        dict['rank']=tag_li.find('em').string
        dict['name']=tag_li.find_all('span','title')[0].string
        dict['score']=tag_li.find('span','rating_num').string
        if(tag_li.find('span','inq')):
            dict['desc']=tag_li.find('span','inq').string
        movies_list.append(dict)
    return movies_list

if __name__ == "__main__":
#     root_url="https://movie.douban.com/top250"
    root_url = "https://movie.douban.com/subject_search?search_text=%s"
#     root_url = "https://search.douban.com/movie/subject_search?search_text=%s&cat=1002"
#     raw_in = raw_input("name:")
    raw_in = '功夫'
    
    if raw_in is not None:
        root_url = root_url%(raw_in)
        print root_url
        html = urllib2.urlopen(root_url)
        html_data = html.read()
        soup = BeautifulSoup(html_data, 'html.parser')
#         print soup
        content = soup.find("div", {"id":"wrapper"})
        if content:
            print content
        else:
            print "None"


    #     start=0
#     while(start<250):
#         movies_list=get_review(get_url(root_url,start))
#         for movie_dict in movies_list:
#             print(u'电影排名：'+movie_dict['rank'])
#             print(u'电影名称：'+movie_dict.get('name'))
#             print(u'电影评分：'+movie_dict.get('score'))
#             print(u'电影评词：'+movie_dict.get('desc',u'无评词'))
#             print('------------------------------------------------------')
#         start+=25
# Out:
# https://movie.douban.com/subject_search?search_text=功夫
# <div id="wrapper">
# <div class="root" id="root">
# <div class="search-title">正在搜索...</div>
# </div>
# <div id="browser-support"></div>
# <div id="footer">
# <span class="fleft gray-link" id="icp">
#     © 2005－2019 douban.com, all rights reserved 北京豆网科技有限公司
# </span>
# <a href="https://www.douban.com/hnypt/variformcyst.py" style="display: none;"></a>
# <span class="fright">
# <a href="https://www.douban.com/about">关于豆瓣</a>
#     · <a href="https://www.douban.com/jobs">在豆瓣工作</a>
#     · <a href="https://www.douban.com/about?topic=contactus">联系我们</a>
#     · <a href="https://www.douban.com/about/legal">法律声明</a>
#
#     · <a href="https://help.douban.com/?app=main" target="_blank">帮助中心</a>
#     · <a href="https://www.douban.com/doubanapp/">移动应用</a>
#     · <a href="https://www.douban.com/partner/">豆瓣广告</a>
# </span>
# </div>
# </div>

# %%
douban_root='https://movie.douban.com/subject_search?search_text=%s&cat=1002'

# %% [markdown]
# # douban

# %% [markdown]
# ## ID

# %%
#### -*- coding:utf-8 -*-
import urllib2
import json
from bs4 import BeautifulSoup
from urllib2 import quote, unquote
import time
import re

root_url ='https://movie.douban.com/subject/%s/'
      
def search_douban_VIP(search_url):    
    html = urllib2.urlopen(search_url)
    html_data = html.read()
    soup = BeautifulSoup(html_data, 'html.parser')
    print soup
    content = soup.find_all("title")
    if content:
        print content[0].get_text().strip()
        cont = soup.find("script", {"type":"application/ld+json"})
        mvdict = {}
        if cont :
#             print cont.get_text()
            cont_dic = eval(cont.contents[0])
        
            def get_cont_dic(cont_dic,mvdict,key):
                director = (cont_dic[key])
            
                if key in ['director','author','actor']:
                    if len(director) > 1:
                        d_name = ''
                        for x in director:
                            if len(d_name) > 2:
                                if len(d_name.split(',')) < 6:
                                    d_name = d_name +','+(dict(x)['name'].split()[0])
                                else:
                                    break
                            else:
                                d_name = (dict(x)['name'].split()[0])
#                             print d_name,dict(x)['name'].split()[0]
                        mvdict[key] = d_name
                    else:
#                         print dict(director[0])['name'].split()[0]
                        mvdict[key] = dict(director[0])['name'].split()[0]
#                     if key == 'actor':
#                         if (mvdict[key].split(',')) > 5:
#                             continue
                elif key in ['description']:
                    print director
                    mvdict[key] =  director.strip()
                elif key in ['aggregateRating']:
#                     print dict(director)['ratingValue']
                    mvdict[key] = dict(director)['ratingValue']  
            
                return mvdict

#             for key in ['director','author','actor','description','aggregateRating']:
            for key in ['director','actor','description','aggregateRating']:
                mvdict = get_cont_dic(cont_dic,mvdict,key)
                print "%s : %s"%(key,mvdict[key])
#             print  mvdict
#         print  re_script.sub('',cont) #去掉SCRIPT
#     _playlist = soup.find("div", {"class":"_playlist"}).find_all("i",{"class":"icon_sm icon_play_sm"})
#     content_playlist = soup.find_all("div", {"class":"_playlist"})
#     content_playsrc = soup.find_all("div", {"class":"_playsrc"})

while 1:
#     file_name = raw_input("输入douban:")
    file_name = '27166976'
    print "url: %s"%(root_url%file_name)
    search_douban_VIP(root_url%file_name)
    break
# Out:
# url: https://movie.douban.com/subject/27166976/
# <!DOCTYPE html>
#
# <html class="" lang="zh-cmn-Hans">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="webkit" name="renderer">
# <meta content="always" name="referrer">
# <meta content="ok0wCgT20tBBgo9_zat2iAcimtN4Ftf5ccsh092Xeyw" name="google-site-verification"/>
# <title>
#         安娜 (豆瓣)
# </title>
# <meta content="cZdR4xxR7RxmM4zE" name="baidu-site-verification"/>
# <meta content="no-cache" http-equiv="Pragma">
# <meta content="Sun, 6 Mar 2005 01:00:00 GMT" http-equiv="Expires">
# <link href="https://img3.doubanio.com/f/movie/d59b2715fdea4968a450ee5f6c95c7d7a2030065/pics/movie/apple-touch-icon.png" rel="apple-touch-icon">
# <link href="https://img3.doubanio.com/f/shire/52c9997d6d42db58eab418e976a14d5f3eff981e/css/douban.css" rel="stylesheet" type="text/css">
# <link href="https://img3.doubanio.com/f/shire/ae3f5a3e3085968370b1fc63afcecb22d3284848/css/separation/_all.css" rel="stylesheet" type="text/css">
# <link href="https://img3.doubanio.com/f/movie/8864d3756094f5272d3c93e30ee2e324665855b0/css/movie/base/init.css" rel="stylesheet">
# <script type="text/javascript">var _head_start = new Date();</script>
# <script src="https://img3.doubanio.com/f/movie/0495cb173e298c28593766009c7b0a953246c5b5/js/movie/lib/jquery.js" type="text/javascript"></script>
# <script src="https://img3.doubanio.com/f/shire/5ecaf46d6954d5a30bc7d99be86ae34031646e00/js/douban.js" type="text/javascript"></script>
# <script src="https://img3.doubanio.com/f/shire/0efdc63b77f895eaf85281fb0e44d435c6239a3f/js/separation/_all.js" type="text/javascript"></script>
# <meta content="安娜,Anna,安娜影评,剧情介绍,电影图片,预告片,影讯,在线购票,论坛" name="keywords">
# <meta content="安娜电影简介和剧情介绍,安娜影评、图片、预告片、影讯、论坛、在线购票" name="description">
# <meta content="format=html5; url=http://m.douban.com/movie/subject/27166976/" name="mobile-agent"/>
# <link href="android-app://com.douban.movie/doubanmovie/subject/27166976/" rel="alternate"/>
# <link href="https://img3.doubanio.com/dae/cdnlib/libs/LikeButton/1.0.5/style.min.css" rel="stylesheet">
# <script data-cfg-autoload="false" src="https://img3.doubanio.com/f/shire/77323ae72a612bba8b65f845491513ff3329b1bb/js/do.js" type="text/javascript"></script>
# <script type="text/javascript">
#       Do.add('dialog', {path: 'https://img3.doubanio.com/f/shire/383a6e43f2108dc69e3ff2681bc4dc6c72a5ffb0/js/ui/dialog.js', type: 'js'});
#       Do.add('dialog-css', {path: 'https://img3.doubanio.com/f/shire/8377b9498330a2e6f056d863987cc7a37eb4d486/css/ui/dialog.css', type: 'css'});
#       Do.add('handlebarsjs', {path: 'https://img3.doubanio.com/f/movie/3d4f8e4a8918718256450eb6e57ec8e1f7a2e14b/js/movie/lib/handlebars.current.js', type: 'js'});
#     </script>
# <script type="text/javascript">
#   var _vwo_code = (function() {
#     var account_id = 249272,
#       settings_tolerance = 0,
#       library_tolerance = 2500,
#       use_existing_jquery = false,
#       // DO NOT EDIT BELOW THIS LINE
#       f=false,d=document;return{use_existing_jquery:function(){return use_existing_jquery;},library_tolerance:function(){return library_tolerance;},finish:function(){if(!f){f=true;var a=d.getElementById('_vis_opt_path_hides');if(a)a.parentNode.removeChild(a);}},finished:function(){return f;},load:function(a){var b=d.createElement('script');b.src=a;b.type='text/javascript';b.innerText;b.onerror=function(){_vwo_code.finish();};d.getElementsByTagName('head')[0].appendChild(b);},init:function(){settings_timer=setTimeout('_vwo_code.finish()',settings_tolerance);var a=d.createElement('style'),b='body{opacity:0 !important;filter:alpha(opacity=0) !important;background:none !important;}',h=d.getElementsByTagName('head')[0];a.setAttribute('id','_vis_opt_path_hides');a.setAttribute('type','text/css');if(a.styleSheet)a.styleSheet.cssText=b;else a.appendChild(d.createTextNode(b));h.appendChild(a);this.load('//dev.visualwebsiteoptimizer.com/j.php?a='+account_id+'&u='+encodeURIComponent(d.URL)+'&r='+Math.random());return settings_timer;}};}());
#
#   +function () {
#     var bindEvent = function (el, type, handler) {
#         var $ = window.jQuery || window.Zepto || window.$
#        if ($ && $.fn && $.fn.on) {
#            $(el).on(type, handler)
#        } else if($ && $.fn && $.fn.bind) {
#            $(el).bind(type, handler)
#        } else if (el.addEventListener){
#          el.addEventListener(type, handler, false);
#        } else if (el.attachEvent){
#          el.attachEvent("on" + type, handler);
#        } else {
#          el["on" + type] = handler;
#        }
#      }
#
#     var _origin_load = _vwo_code.load
#     _vwo_code.load = function () {
#       var args = [].slice.call(arguments)
#       bindEvent(window, 'load', function () {
#         _origin_load.apply(_vwo_code, args)
#       })
#     }
#   }()
#
#   _vwo_settings_timer = _vwo_code.init();
#   </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "name": "安娜 Anna",
#   "url": "/subject/27166976/",
#   "image": "https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2553320254.jpg",
#   "director":
#   [
#     {
#       "@type": "Person",
#       "url": "/celebrity/1031876/",
#       "name": "吕克·贝松 Luc Besson"
#     }
#   ]
# ,
#   "author":
#   [
#     {
#       "@type": "Person",
#       "url": "/celebrity/1031876/",
#       "name": "吕克·贝松 Luc Besson"
#     }
#   ]
# ,
#   "actor":
#   [
#     {
#       "@type": "Person",
#       "url": "/celebrity/1382297/",
#       "name": "萨莎·露丝 Sasha Luss"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1054390/",
#       "name": "海伦·米伦 Helen Mirren"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1276136/",
#       "name": "卢克·伊万斯 Luke Evans"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1047992/",
#       "name": "基里安·墨菲 Cillian Murphy"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1418363/",
#       "name": "莱拉·阿波瓦 Lera Abova"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1370381/",
#       "name": "亚历山大·佩特罗夫 Alexander Petrov"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1422954/",
#       "name": "尼基塔·帕夫连科 Nikita Pavlenko"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1422955/",
#       "name": "安娜·克里帕 Anna Krippa"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1422956/",
#       "name": "阿列克谢·马斯洛杜多夫 Aleksey Maslodudov"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1009215/",
#       "name": "艾力克·高敦 Eric Godon"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1387919/",
#       "name": "伊凡·弗拉内克 Ivan Franek"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1422953/",
#       "name": "让·巴蒂斯特·普奇 Jean-Baptiste Puech"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1378475/",
#       "name": "阿德里安·坎恩 Adrian Can"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1422957/",
#       "name": "艾莉森·惠勒 Alison Wheeler"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1286986/",
#       "name": "安德鲁·霍华德 Andrew Howard"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1339838/",
#       "name": "詹·奥利弗·施罗德 Jan Oliver Schroeder"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1361491/",
#       "name": "谢尔盖·巴切乌尔斯基 Sergey Bachurskiy"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1323451/",
#       "name": "耶斯·利奥丹 Jess Liaudin"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1257486/",
#       "name": "詹姆斯·乔因特 James Joint"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1412921/",
#       "name": "雷吉尔·库迪乌 Réginal Kudiwu"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1381552/",
#       "name": "扎克·安德里亚纳索洛 Zac Andrianasolo"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1384004/",
#       "name": "保利妮·霍劳 Pauline Hoarau"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1051336/",
#       "name": "尼可洛·森尼 Niccolò Senni"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1361497/",
#       "name": "伊戈尔·萨沃金 Igor Savochkin"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1042811/",
#       "name": "特拉维斯·克舍琴 Travis Kerschen"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1393293/",
#       "name": "埃文特·斯特朗 Avant Strangel"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1339842/",
#       "name": "克里斯多夫·泰克 Christophe Tek"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1406479/",
#       "name": "鲁伯特·韦恩-詹姆斯 Rupert Wynne-James"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1068041/",
#       "name": "大卫·科伯恩 David Coburn"
#     }
#     ,
#     {
#       "@type": "Person",
#       "url": "/celebrity/1423076/",
#       "name": "詹苏·托松 cansu tosun"
#     }
#   ]
# ,
#   "datePublished": "2019-06-21",
#   "genre": ["\u52a8\u4f5c", "\u60ca\u609a"],
#   "duration": "PT1H59M",
#   "description": "故事聚焦神秘女杀手安娜的成长及执行各种暗杀任务的经历，在美丽的外表下，安娜拥有聪明绝顶的头脑和强大的战斗技巧，是世界上最恐怖的刺客之一，她游走于黑白两道，只要被锁定的目标，从不失手。",
#   "@type": "Movie",
#   "aggregateRating": {
#     "@type": "AggregateRating",
#     "ratingCount": "57562",
#     "bestRating": "10",
#     "worstRating": "2",
#     "ratingValue": "7.7"
#   }
# }
# </script>
# <style type="text/css">
# </style>
# <style type="text/css">img { max-width: 100%; }</style>
# <script type="text/javascript"></script>
# <link href="https://img3.doubanio.com/misc/mixed_static/77480d92e534c81c.css" rel="stylesheet">
# <link href="https://img3.doubanio.com/favicon.ico" rel="shortcut icon" type="image/x-icon">
# </link></link></link></meta></meta></link></link></link></link></meta></meta></meta></meta></meta></head>
# <body>
# <script type="text/javascript">var _body_start = new Date();</script>
# <link href="//img3.doubanio.com/dae/accounts/resources/a4a38a5/shire/bundle.css" rel="stylesheet" type="text/css">
# <div class="global-nav" id="db-global-nav">
# <div class="bd">
# <div class="top-nav-info">
# <a class="nav-login" href="https://accounts.douban.com/passport/login?source=movie" rel="nofollow">登录/注册</a>
# </div>
# <div class="top-nav-doubanapp">
# <a class="lnk-doubanapp" href="https://www.douban.com/doubanapp/app?channel=top-nav">下载豆瓣客户端</a>
# <div id="doubanapp-tip">
# <a class="tip-link" href="https://www.douban.com/doubanapp/app?channel=qipao">豆瓣 <span class="version">6.0</span> 全新发布</a>
# <a class="tip-close" href="javascript: void 0;">×</a>
# </div>
# <div class="more-items" id="top-nav-appintro">
# <p class="appintro-title">豆瓣</p>
# <p class="qrcode">扫码直接下载</p>
# <div class="download">
# <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&amp;direct_dl=1&amp;download=iOS">iPhone</a>
# <span>·</span>
# <a class="download-android" href="https://www.douban.com/doubanapp/redirect?channel=top-nav&amp;direct_dl=1&amp;download=Android">Android</a>
# </div>
# </div>
# </div>
# <div class="global-nav-items">
# <ul>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-main","uid":"0"}' href="https://www.douban.com" target="_blank">豆瓣</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-book","uid":"0"}' href="https://book.douban.com" target="_blank">读书</a>
# </li>
# <li class="on">
# <a data-moreurl-dict='{"from":"top-nav-click-movie","uid":"0"}' href="https://movie.douban.com">电影</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-music","uid":"0"}' href="https://music.douban.com" target="_blank">音乐</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-location","uid":"0"}' href="https://www.douban.com/location" target="_blank">同城</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-group","uid":"0"}' href="https://www.douban.com/group" target="_blank">小组</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-read","uid":"0"}' href="https://read.douban.com/?dcs=top-nav&amp;dcm=douban" target="_blank">阅读</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-fm","uid":"0"}' href="https://douban.fm/?from_=shire_top_nav" target="_blank">FM</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-time","uid":"0"}' href="https://time.douban.com/?dt_time_source=douban-web_top_nav" target="_blank">时间</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-market","uid":"0"}' href="https://market.douban.com/?utm_campaign=douban_top_nav&amp;utm_source=douban&amp;utm_medium=pc_web" target="_blank">豆品</a>
# </li>
# <li>
# <a class="bn-more" href="#more"><span>更多</span></a>
# <div class="more-items">
# <table cellpadding="0" cellspacing="0">
# <tbody>
# <tr>
# <td>
# <a data-moreurl-dict='{"from":"top-nav-click-ypy","uid":"0"}' href="https://ypy.douban.com" target="_blank">豆瓣摄影</a>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <script>
#   ;window._GLOBAL_NAV = {
#     DOUBAN_URL: "https://www.douban.com",
#     N_NEW_NOTIS: 0,
#     N_NEW_DOUMAIL: 0
#   };
# </script>
# <script defer="defer" src="//img3.doubanio.com/dae/accounts/resources/a4a38a5/shire/bundle.js"></script>
# <link href="//img3.doubanio.com/dae/accounts/resources/a4a38a5/movie/bundle.css" rel="stylesheet" type="text/css">
# <div class="nav" id="db-nav-movie">
# <div class="nav-wrap">
# <div class="nav-primary">
# <div class="nav-logo">
# <a href="https://movie.douban.com">豆瓣电影</a>
# </div>
# <div class="nav-search">
# <form action="https://search.douban.com/movie/subject_search" method="get">
# <fieldset>
# <legend>搜索：</legend>
# <label for="inp-query">
# </label>
# <div class="inp"><input id="inp-query" maxlength="60" name="search_text" placeholder="搜索电影、电视剧、综艺、影人" size="22" value=""/></div>
# <div class="inp-btn"><input type="submit" value="搜索"/></div>
# <input name="cat" type="hidden" value="1002"/>
# </fieldset>
# </form>
# </div>
# </div>
# </div>
# <div class="nav-secondary">
# <div class="nav-items">
# <ul>
# <li><a href="https://movie.douban.com/cinema/nowplaying/">影讯&amp;购票</a>
# </li>
# <li><a href="https://movie.douban.com/explore">选电影</a>
# </li>
# <li><a href="https://movie.douban.com/tv/">电视剧</a>
# </li>
# <li><a href="https://movie.douban.com/chart">排行榜</a>
# </li>
# <li><a href="https://movie.douban.com/tag/">分类</a>
# </li>
# <li><a href="https://movie.douban.com/review/best/">影评</a>
# </li>
# <li><a href="https://movie.douban.com/annual/2018?source=navigation">2018年度榜单</a>
# </li>
# <li><a href="https://www.douban.com/standbyme/2018?source=navigation">2018书影音报告</a>
# </li>
# </ul>
# </div>
# <a class="movieannual2018" href="https://movie.douban.com/annual/2018?source=movie_navigation"></a>
# </div>
# </div>
# <script id="suggResult" type="text/x-jquery-tmpl">
#   <li data-link="{{= url}}">
#             <a href="{{= url}}" onclick="moreurl(this, {from:'movie_search_sugg', query:'{{= keyword }}', subject_id:'{{= id}}', i: '{{= index}}', type: '{{= type}}'})">
#             <img src="{{= img}}" width="40" />
#             <p>
#                 <em>{{= title}}</em>
#                 {{if year}}
#                     <span>{{= year}}</span>
#                 {{/if}}
#                 {{if sub_title}}
#                     <br /><span>{{= sub_title}}</span>
#                 {{/if}}
#                 {{if address}}
#                     <br /><span>{{= address}}</span>
#                 {{/if}}
#                 {{if episode}}
#                     {{if episode=="unknow"}}
#                         <br /><span>集数未知</span>
#                     {{else}}
#                         <br /><span>共{{= episode}}集</span>
#                     {{/if}}
#                 {{/if}}
#             </p>
#         </a>
#         </li>
#   </script>
# <script defer="defer" src="//img3.doubanio.com/dae/accounts/resources/a4a38a5/movie/bundle.js"></script>
# <div id="wrapper">
# <div id="content">
# <div id="dale_movie_subject_top_icon"></div>
# <h1>
# <span property="v:itemreviewed">安娜 Anna</span>
# <span class="year">(2019)</span>
# </h1>
# <div class="grid-16-8 clearfix">
# <div class="article">
# <div class="indent clearfix">
# <div class="subjectwrap clearfix">
# <div class="subject clearfix">
# <div class="" id="mainpic">
# <a class="nbgnbg" href="https://movie.douban.com/subject/27166976/photos?type=R" title="点击看更多海报">
# <img alt="Anna" rel="v:image" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2553320254.jpg" title="点击看更多海报"/>
# </a>
# </div>
# <div id="info">
# <span><span class="pl">导演</span>: <span class="attrs"><a href="/celebrity/1031876/" rel="v:directedBy">吕克·贝松</a></span></span><br/>
# <span><span class="pl">编剧</span>: <span class="attrs"><a href="/celebrity/1031876/">吕克·贝松</a></span></span><br/>
# <span class="actor"><span class="pl">主演</span>: <span class="attrs"><a href="/celebrity/1382297/" rel="v:starring">萨莎·露丝</a> / <a href="/celebrity/1054390/" rel="v:starring">海伦·米伦</a> / <a href="/celebrity/1276136/" rel="v:starring">卢克·伊万斯</a> / <a href="/celebrity/1047992/" rel="v:starring">基里安·墨菲</a> / <a href="/celebrity/1418363/" rel="v:starring">莱拉·阿波瓦</a> / <a href="/celebrity/1370381/" rel="v:starring">亚历山大·佩特罗夫</a> / <a href="/celebrity/1422954/" rel="v:starring">尼基塔·帕夫连科</a> / <a href="/celebrity/1422955/" rel="v:starring">安娜·克里帕</a> / <a href="/celebrity/1422956/" rel="v:starring">阿列克谢·马斯洛杜多夫</a> / <a href="/celebrity/1009215/" rel="v:starring">艾力克·高敦</a> / <a href="/celebrity/1387919/" rel="v:starring">伊凡·弗拉内克</a> / <a href="/celebrity/1422953/" rel="v:starring">让·巴蒂斯特·普奇</a> / <a href="/celebrity/1378475/" rel="v:starring">阿德里安·坎恩</a> / <a href="/celebrity/1422957/" rel="v:starring">艾莉森·惠勒</a> / <a href="/celebrity/1286986/" rel="v:starring">安德鲁·霍华德</a> / <a href="/celebrity/1339838/" rel="v:starring">詹·奥利弗·施罗德</a> / <a href="/celebrity/1361491/" rel="v:starring">谢尔盖·巴切乌尔斯基</a> / <a href="/celebrity/1323451/" rel="v:starring">耶斯·利奥丹</a> / <a href="/celebrity/1257486/" rel="v:starring">詹姆斯·乔因特</a> / <a href="/celebrity/1412921/" rel="v:starring">雷吉尔·库迪乌</a> / <a href="/celebrity/1381552/" rel="v:starring">扎克·安德里亚纳索洛</a> / <a href="/celebrity/1384004/" rel="v:starring">保利妮·霍劳</a> / <a href="/celebrity/1051336/" rel="v:starring">尼可洛·森尼</a> / <a href="/celebrity/1361497/" rel="v:starring">伊戈尔·萨沃金</a> / <a href="/celebrity/1042811/" rel="v:starring">特拉维斯·克舍琴</a> / <a href="/celebrity/1393293/" rel="v:starring">埃文特·斯特朗</a> / <a href="/celebrity/1339842/" rel="v:starring">克里斯多夫·泰克</a> / <a href="/celebrity/1406479/" rel="v:starring">鲁伯特·韦恩-詹姆斯</a> / <a href="/celebrity/1068041/" rel="v:starring">大卫·科伯恩</a></span></span><br/>
# <span class="pl">类型:</span> <span property="v:genre">动作</span> / <span property="v:genre">惊悚</span><br/>
# <span class="pl">官方网站:</span> <a href="http://anna.movie" rel="nofollow" target="_blank">anna.movie</a><br/>
# <span class="pl">制片国家/地区:</span> 法国 / 美国<br/>
# <span class="pl">语言:</span> 英语 / 俄语 / 法语<br/>
# <span class="pl">上映日期:</span> <span content="2019-06-21(美国)" property="v:initialReleaseDate">2019-06-21(美国)</span> / <span content="2019-07-10(法国)" property="v:initialReleaseDate">2019-07-10(法国)</span><br/>
# <span class="pl">片长:</span> <span content="119" property="v:runtime">119分钟</span><br/>
# <span class="pl">又名:</span> ANИA<br/>
# <span class="pl">IMDb链接:</span> <a href="https://www.imdb.com/title/tt7456310" rel="nofollow" target="_blank">tt7456310</a><br>
# </br></div>
# </div>
# <div id="interest_sectl">
# <div class="rating_wrap clearbox" rel="v:rating">
# <div class="clearfix">
# <div class="rating_logo ll">豆瓣评分</div>
# <div class="output-btn-wrap rr" style="display:none">
# <img src="https://img3.doubanio.com/f/movie/692e86756648f29457847c5cc5e161d6f6b8aaac/pics/movie/reference.png"/>
# <a class="download-output-image" href="#">引用</a>
# </div>
# </div>
# <div class="rating_self clearfix" typeof="v:Rating">
# <strong class="ll rating_num" property="v:average">7.7</strong>
# <span content="10.0" property="v:best"></span>
# <div class="rating_right ">
# <div class="ll bigstar bigstar40"></div>
# <div class="rating_sum">
# <a class="rating_people" href="collections">
# <span property="v:votes">57579</span>人评价
#                 </a>
# </div>
# </div>
# </div>
# <div class="ratings-on-weight">
# <div class="item">
# <span class="stars5 starstop" title="力荐">
#             5星
#         </span>
# <div class="power" style="width:25px"></div>
# <span class="rating_per">19.2%</span>
# <br/>
# </div>
# <div class="item">
# <span class="stars4 starstop" title="推荐">
#             4星
#         </span>
# <div class="power" style="width:64px"></div>
# <span class="rating_per">48.2%</span>
# <br/>
# </div>
# <div class="item">
# <span class="stars3 starstop" title="还行">
#             3星
#         </span>
# <div class="power" style="width:38px"></div>
# <span class="rating_per">29.2%</span>
# <br/>
# </div>
# <div class="item">
# <span class="stars2 starstop" title="较差">
#             2星
#         </span>
# <div class="power" style="width:3px"></div>
# <span class="rating_per">3.0%</span>
# <br/>
# </div>
# <div class="item">
# <span class="stars1 starstop" title="很差">
#             1星
#         </span>
# <div class="power" style="width:0px"></div>
# <span class="rating_per">0.5%</span>
# <br/>
# </div>
# </div>
# </div>
# <div class="rating_betterthan">
#             好于 <a href="/typerank?type_name=动作&amp;type=5&amp;interval_id=90:80&amp;action=">85% 动作片</a><br/>
#             好于 <a href="/typerank?type_name=惊悚&amp;type=19&amp;interval_id=90:80&amp;action=">85% 惊悚片</a><br/>
# </div>
# </div>
# </div>
# <div class="clearfix" id="interest_sect_level">
# <a class="j a_show_login colbutt ll" href="https://www.douban.com/reason=collectwish&amp;ck=" name="pbtn-27166976-wish" rel="nofollow">
# <span>想看</span>
# </a>
# <a class="j a_show_login colbutt ll" href="https://www.douban.com/reason=collectcollect&amp;ck=" name="pbtn-27166976-collect" rel="nofollow">
# <span>看过</span>
# </a>
# <div class="ll j a_stars">
#
#
#     评价:
#     <span id="rating"> <span data-hollow="https://img3.doubanio.com/f/shire/2520c01967207a1735171056ec588c8c1257e5f8/pics/rating_icons/star_hollow_hover.png" data-hollow-2x="https://img3.doubanio.com/f/shire/95cc2fa733221bb8edd28ad56a7145a5ad33383e/pics/rating_icons/star_hollow_hover@2x.png" data-solid="https://img3.doubanio.com/f/shire/5a2327c04c0c231bced131ddf3f4467eb80c1c86/pics/rating_icons/star_onmouseover.png" data-solid-2x="https://img3.doubanio.com/f/shire/7258904022439076d57303c3b06ad195bf1dc41a/pics/rating_icons/star_onmouseover@2x.png" id="stars">
# <a class="j a_show_login" href="https://www.douban.com/register?reason=rate" name="pbtn-27166976-1">
# <img height="16" id="star1" src="https://img3.doubanio.com/f/shire/2520c01967207a1735171056ec588c8c1257e5f8/pics/rating_icons/star_hollow_hover.png" width="16"/></a>
# <a class="j a_show_login" href="https://www.douban.com/register?reason=rate" name="pbtn-27166976-2">
# <img height="16" id="star2" src="https://img3.doubanio.com/f/shire/2520c01967207a1735171056ec588c8c1257e5f8/pics/rating_icons/star_hollow_hover.png" width="16"/></a>
# <a class="j a_show_login" href="https://www.douban.com/register?reason=rate" name="pbtn-27166976-3">
# <img height="16" id="star3" src="https://img3.doubanio.com/f/shire/2520c01967207a1735171056ec588c8c1257e5f8/pics/rating_icons/star_hollow_hover.png" width="16"/></a>
# <a class="j a_show_login" href="https://www.douban.com/register?reason=rate" name="pbtn-27166976-4">
# <img height="16" id="star4" src="https://img3.doubanio.com/f/shire/2520c01967207a1735171056ec588c8c1257e5f8/pics/rating_icons/star_hollow_hover.png" width="16"/></a>
# <a class="j a_show_login" href="https://www.douban.com/register?reason=rate" name="pbtn-27166976-5">
# <img height="16" id="star5" src="https://img3.doubanio.com/f/shire/2520c01967207a1735171056ec588c8c1257e5f8/pics/rating_icons/star_hollow_hover.png" width="16"/></a>
# </span><span class="pl" id="rateword"></span>
# <input id="n_rating" type="hidden" value=""/>
# </span>
# </div>
# </div>
# <div class="gtleft">
# <ul class="ul_subject_menu bicelink color_gray pt6 clearfix">
# <li>
# <img src="https://img3.doubanio.com/f/shire/cc03d0fcf32b7ce3af7b160a0b85e5e66b47cc42/pics/short-comment.gif"/>
#         <a class="j a_show_login" href="https://www.douban.com/register?reason=review" onclick="moreurl(this, {from:'mv_sbj_wr_cmnt_login'})" rel="nofollow">写短评</a>
# </li>
# <li>
# <img src="https://img3.doubanio.com/f/shire/5bbf02b7b5ec12b23e214a580b6f9e481108488c/pics/add-review.gif"/>
#         <a class="j a_show_login" href="https://www.douban.com/register?reason=review" onclick="moreurl(this, {from:'mv_sbj_wr_rv_login'})" rel="nofollow">写影评</a>
# </li>
# <li>
# </li>
# <li>
# <span class="rec" id="电影-27166976">
# <a class="bn-sharing " data-desc="电影《安娜 Anna》 (来自豆瓣) " data-pic="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2553320254.jpeg" data-title="电影《安娜 Anna》 (来自豆瓣) " data-type="电影" data-url="https://movie.douban.com/subject/27166976/" href="#">
#         分享到
#     </a>
#     </span>
# <script>
#         if (!window.DoubanShareMenuList) {
#             window.DoubanShareMenuList = [];
#         }
#         var __cache_url = __cache_url || {};
#
#         (function(u){
#             if(__cache_url[u]) return;
#             __cache_url[u] = true;
#             window.DoubanShareIcons = 'https://img3.doubanio.com/f/shire/d15ffd71f3f10a7210448fec5a68eaec66e7f7d0/pics/ic_shares.png';
#
#             var initShareButton = function() {
#                 $.ajax({url:u,dataType:'script',cache:true});
#             };
#
#             if (typeof Do == 'function' && 'ready' in Do) {
#                 Do(
#                     'https://img3.doubanio.com/f/shire/8377b9498330a2e6f056d863987cc7a37eb4d486/css/ui/dialog.css',
#                     'https://img3.doubanio.com/f/shire/383a6e43f2108dc69e3ff2681bc4dc6c72a5ffb0/js/ui/dialog.js',
#                     'https://img3.doubanio.com/f/movie/c4ab132ff4d3d64a83854c875ea79b8b541faf12/js/movie/lib/qrcode.min.js',
#                     initShareButton
#                 );
#             } else if(typeof Douban == 'object' && 'loader' in Douban) {
#                 Douban.loader.batch(
#                     'https://img3.doubanio.com/f/shire/8377b9498330a2e6f056d863987cc7a37eb4d486/css/ui/dialog.css',
#                     'https://img3.doubanio.com/f/shire/383a6e43f2108dc69e3ff2681bc4dc6c72a5ffb0/js/ui/dialog.js',
#                     'https://img3.doubanio.com/f/movie/c4ab132ff4d3d64a83854c875ea79b8b541faf12/js/movie/lib/qrcode.min.js'
#                 ).done(initShareButton);
#             }
#
#         })('https://img3.doubanio.com/f/movie/32be6727ed3ad8f6c4a417d8a086355c3e7d1d27/js/movie/lib/sharebutton.js');
#     </script>
# </li>
# </ul>
# <script type="text/javascript">
#         $(function(){
#             $(".ul_subject_menu li.rec .bn-sharing").bind("click", function(){
#                 $.get("/blank?sbj_page_click=bn_sharing");
#             });
#             $(".ul_subject_menu .create_from_menu").bind("click", function(e){
#                 e.preventDefault();
#                 var $el = $(this);
#                 var glRoot = document.getElementById('gallery-topics-selection');
#                 if (window.has_gallery_topics && glRoot) {
#                     // 判断是否有话题
#                     glRoot.style.display = 'block';
#                 } else {
#                     location.href = $el.attr('href');
#                 }
#             });
#         });
#     </script>
# </div>
# <div class="rec-sec">
# <span class="rec">
# <script id="movie-share" type="text/x-html-snippet">
#
#     <form class="movie-share" action="/j/share" method="POST">
#         <div class="clearfix form-bd">
#             <div class="input-area">
#                 <textarea name="text" class="share-text" cols="72" data-mention-api="https://api.douban.com/shuo/in/complete?alt=xd&amp;callback=?"></textarea>
#                 <input type="hidden" name="target-id" value="27166976">
#                 <input type="hidden" name="target-type" value="0">
#                 <input type="hidden" name="title" value="安娜 Anna‎ (2019)">
#                 <input type="hidden" name="desc" value="导演 吕克·贝松 主演 萨莎·露丝 / 海伦·米伦 / 法国 / 美国 / 7.7分(57579评价)">
#                 <input type="hidden" name="redir" value=""/>
#                 <div class="mentioned-highlighter"></div>
#             </div>
#
#             <div class="info-area">
#                     <img class="media" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2553320254.jpg" />
#                 <strong>安娜 Anna‎ (2019)</strong>
#                 <p>导演 吕克·贝松 主演 萨莎·露丝 / 海伦·米伦 / 法国 / 美国 / 7.7分(57579评价)</p>
#                 <p class="error server-error">&nbsp;</p>
#             </div>
#         </div>
#         <div class="form-ft">
#             <div class="form-ft-inner">
#
#
#
#
#                 <span class="avail-num-indicator">140</span>
#                 <span class="bn-flat">
#                     <input type="submit" value="推荐" />
#                 </span>
#             </div>
#         </div>
#     </form>
#
#     <div id="suggest-mention-tmpl" style="display:none;">
#         <ul>
#             {{#users}}
#             <li id="{{uid}}">
#               <img src="{{avatar}}">{{{username}}}&nbsp;<span>({{{uid}}})</span>
#             </li>
#             {{/users}}
#         </ul>
#     </div>
#
#
#     </script>
# <a class="j a_show_login lnk-sharing" data-action_props='{"subject_url":"https:\/\/movie.douban.com\/subject\/27166976\/","subject_title":"安娜 Anna‎ (2019)"}' data-apikey="" data-count="10" data-curl="" data-desc="导演 吕克·贝松 主演 萨莎·露丝 / 海伦·米伦 / 法国 / 美国 / 7.7分(57579评价)" data-href="https://movie.douban.com/subject/27166976/" data-image="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2553320254.jpg" data-mode="plain" data-name="安娜 Anna‎ (2019)" data-object_id="27166976" data-object_kind="1002" data-properties="{}" data-redir="" data-target_action="0" data-target_type="rec" data-text="" data-type="movie" href="/accounts/register?reason=recommend" share-id="27166976">推荐</a>
# </span>
# </div>
# <script type="text/javascript">
#                 $(function() {
#                     $('.collect_btn', '#interest_sect_level').each(function() {
#                         Douban.init_collect_btn(this);
#                     });
#                     $('html').delegate(".indent .rec-sec .lnk-sharing", "click", function() {
#                         moreurl(this, {
#                             from : 'mv_sbj_db_share'
#                         });
#                     });
#                 });
#             </script>
# </div>
# <div id="collect_form_27166976"></div>
# <div class="related-info" style="margin-bottom:-10px;">
# <a name="intro"></a>
# <h2>
# <i class="">安娜的剧情简介</i>
#               · · · · · ·
#     </h2>
# <div class="indent" id="link-report">
# <span class="" property="v:summary">
#                                 　　故事聚焦神秘女杀手安娜的成长及执行各种暗杀任务的经历，在美丽的外表下，安娜拥有聪明绝顶的头脑和强大的战斗技巧，是世界上最恐怖的刺客之一，她游走于黑白两道，只要被锁定的目标，从不失手。
#                         </span>
# </div>
# </div>
# <div class="celebrities related-celebrities" id="celebrities">
# <h2>
# <i class="">安娜的演职员</i>
#               · · · · · ·
#             <span class="pl">
#             (
#                 <a href="/subject/27166976/celebrities">全部 31</a>
#             )
#             </span>
# </h2>
# <ul class="celebrities-list from-subject __oneline">
# <li class="celebrity">
# <a class="" href="https://movie.douban.com/celebrity/1031876/" title="吕克·贝松 Luc Besson">
# <div class="avatar" style="background-image: url(https://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p33301.jpg)">
# </div>
# </a>
# <div class="info">
# <span class="name"><a class="name" href="https://movie.douban.com/celebrity/1031876/" title="吕克·贝松 Luc Besson">吕克·贝松</a></span>
# <span class="role" title="导演">导演</span>
# </div>
# </li>
# <li class="celebrity">
# <a class="" href="https://movie.douban.com/celebrity/1382297/" title="萨莎·露丝 Sasha Luss">
# <div class="avatar" style="background-image: url(https://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p1507566906.52.jpg)">
# </div>
# </a>
# <div class="info">
# <span class="name"><a class="name" href="https://movie.douban.com/celebrity/1382297/" title="萨莎·露丝 Sasha Luss">萨莎·露丝</a></span>
# <span class="role" title="饰 Anna">饰 Anna</span>
# </div>
# </li>
# <li class="celebrity">
# <a class="" href="https://movie.douban.com/celebrity/1054390/" title="海伦·米伦 Helen Mirren">
# <div class="avatar" style="background-image: url(https://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p21169.jpg)">
# </div>
# </a>
# <div class="info">
# <span class="name"><a class="name" href="https://movie.douban.com/celebrity/1054390/" title="海伦·米伦 Helen Mirren">海伦·米伦</a></span>
# <span class="role" title="饰 Olga">饰 Olga</span>
# </div>
# </li>
# <li class="celebrity">
# <a class="" href="https://movie.douban.com/celebrity/1276136/" title="卢克·伊万斯 Luke Evans">
# <div class="avatar" style="background-image: url(https://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p36425.jpg)">
# </div>
# </a>
# <div class="info">
# <span class="name"><a class="name" href="https://movie.douban.com/celebrity/1276136/" title="卢克·伊万斯 Luke Evans">卢克·伊万斯</a></span>
# <span class="role" title="饰 Alex Tchenkov">饰 Alex Tchenkov</span>
# </div>
# </li>
# <li class="celebrity">
# <a class="" href="https://movie.douban.com/celebrity/1047992/" title="基里安·墨菲 Cillian Murphy">
# <div class="avatar" style="background-image: url(https://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p1440.jpg)">
# </div>
# </a>
# <div class="info">
# <span class="name"><a class="name" href="https://movie.douban.com/celebrity/1047992/" title="基里安·墨菲 Cillian Murphy">基里安·墨菲</a></span>
# <span class="role" title="饰 Lenny Miller">饰 Lenny Miller</span>
# </div>
# </li>
# <li class="celebrity">
# <a class="" href="https://movie.douban.com/celebrity/1418363/" title="莱拉·阿波瓦 Lera Abova">
# <div class="avatar" style="background-image: url(https://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/pzdsh19_J6HAcel_avatar_uploaded1560615267.65.jpg)">
# </div>
# </a>
# <div class="info">
# <span class="name"><a class="name" href="https://movie.douban.com/celebrity/1418363/" title="莱拉·阿波瓦 Lera Abova">莱拉·阿波瓦</a></span>
# <span class="role" title="饰 Maud">饰 Maud</span>
# </div>
# </li>
# </ul>
# </div>
# <link href="https://img3.doubanio.com/f/verify/16c7e943aee3b1dc6d65f600fcc0f6d62db7dfb4/entry_creator/dist/author_subject/style.css" rel="stylesheet">
# <div class="author-wrapper" id="author_subject">
# <div class="loading"></div>
# </div>
# <script type="text/javascript">
#     var answerObj = {
#       ISALL: 'False',
#       TYPE: 'movie',
#       SUBJECT_ID: '27166976',
#       USER_ID: 'None'
#     }
# </script>
# <script src="https://img3.doubanio.com/f/movie/61252f2f9b35f08b37f69d17dfe48310dd295347/js/movie/lib/react/15.4/bundle.js" type="text/javascript"></script>
# <script src="https://img3.doubanio.com/f/verify/ac140ef86262b845d2be7b859e352d8196f3f6d4/entry_creator/dist/author_subject/index.js" type="text/javascript"></script>
# <div class="related-pic" id="related-pic">
# <h2>
# <i class="">安娜的视频和图片</i>
#               · · · · · ·
#             <span class="pl">
#             (
#                 <a href="https://movie.douban.com/subject/27166976/trailer#trailer">预告片11</a> | <a href="https://movie.douban.com/subject/27166976/trailer#short_video">视频评论1</a> · <a href="/video/create?subject_id=27166976">添加</a> | <a href="https://movie.douban.com/subject/27166976/all_photos">图片636</a> · <a href="https://movie.douban.com/subject/27166976/mupload">添加</a>
#             )
#             </span>
# </h2>
# <ul class="related-pic-bd wide_videos">
# <li class="label-trailer">
# <a class="related-pic-video" href="https://movie.douban.com/trailer/245871/#content" style="background-image:url(https://img3.doubanio.com/img/trailer/medium/2553748741.jpg?)" title="预告片">
# </a>
# </li>
# <li class="label-short-video">
# <a class="related-pic-video" href="https://movie.douban.com/video/103332/" style="background-image:url(https://img1.doubanio.com/view/photo/photo/public/p2560623758.jpg?)" title="视频评论">
# </a>
# </li>
# <li>
# <a href="https://movie.douban.com/photos/photo/2559650985/"><img alt="图片" src="https://img3.doubanio.com/view/photo/sqxs/public/p2559650985.jpg"/></a>
# </li>
# <li>
# <a href="https://movie.douban.com/photos/photo/2559650785/"><img alt="图片" src="https://img3.doubanio.com/view/photo/sqxs/public/p2559650785.jpg"/></a>
# </li>
# </ul>
# </div>
# <style type="text/css">
# .award li { display: inline; margin-right: 5px }
# .awards { margin-bottom: 20px }
# .awards h2 { background: none; color: #000; font-size: 14px; padding-bottom: 5px; margin-bottom: 8px; border-bottom: 1px dashed #dddddd }
# .awards .year { color: #666666; margin-left: -5px }
# .mod { margin-bottom: 25px }
# .mod .hd { margin-bottom: 10px }
# .mod .hd h2 {margin:24px 0 3px 0}
# </style>
# <div class="" id="recommendations">
# <h2>
# <i class="">喜欢这部电影的人也喜欢</i>
#               · · · · · ·
#     </h2>
# <div class="recommendations-bd">
# <dl class="">
# <dt>
# <a href="https://movie.douban.com/subject/26386034/?from=subject-page">
# <img alt="极寒之城" class="" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2461815940.jpg"/>
# </a>
# </dt>
# <dd>
# <a class="" href="https://movie.douban.com/subject/26386034/?from=subject-page">极寒之城</a>
# </dd>
# </dl>
# <dl class="">
# <dt>
# <a href="https://movie.douban.com/subject/26909790/?from=subject-page">
# <img alt="疾速备战" class="" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2551393832.jpg"/>
# </a>
# </dt>
# <dd>
# <a class="" href="https://movie.douban.com/subject/26909790/?from=subject-page">疾速备战</a>
# </dd>
# </dl>
# <dl class="">
# <dt>
# <a href="https://movie.douban.com/subject/26336252/?from=subject-page">
# <img alt="碟中谍6：全面瓦解" class="" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2529365085.jpg"/>
# </a>
# </dt>
# <dd>
# <a class="" href="https://movie.douban.com/subject/26336252/?from=subject-page">碟中谍6：全面瓦解</a>
# </dd>
# </dl>
# <dl class="">
# <dt>
# <a href="https://movie.douban.com/subject/26683421/?from=subject-page">
# <img alt="特工" class="" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2528281606.jpg"/>
# </a>
# </dt>
# <dd>
# <a class="" href="https://movie.douban.com/subject/26683421/?from=subject-page">特工</a>
# </dd>
# </dl>
# <dl class="">
# <dt>
# <a href="https://movie.douban.com/subject/27093707/?from=subject-page">
# <img alt="升级" class="" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2531034314.jpg"/>
# </a>
# </dt>
# <dd>
# <a class="" href="https://movie.douban.com/subject/27093707/?from=subject-page">升级</a>
# </dd>
# </dl>
# <dl class="">
# <dt>
# <a href="https://movie.douban.com/subject/26356631/?from=subject-page">
# <img alt="伸冤人2" class="" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2529742142.jpg"/>
# </a>
# </dt>
# <dd>
# <a class="" href="https://movie.douban.com/subject/26356631/?from=subject-page">伸冤人2</a>
# </dd>
# </dl>
# <dl class="">
# <dt>
# <a href="https://movie.douban.com/subject/26437223/?from=subject-page">
# <img alt="22英里" class="" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2520254064.jpg"/>
# </a>
# </dt>
# <dd>
# <a class="" href="https://movie.douban.com/subject/26437223/?from=subject-page">22英里</a>
# </dd>
# </dl>
# <dl class="">
# <dt>
# <a href="https://movie.douban.com/subject/26580232/?from=subject-page">
# <img alt="看不见的客人" class="" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2498971355.jpg"/>
# </a>
# </dt>
# <dd>
# <a class="" href="https://movie.douban.com/subject/26580232/?from=subject-page">看不见的客人</a>
# </dd>
# </dl>
# <dl class="">
# <dt>
# <a href="https://movie.douban.com/subject/30164448/?from=subject-page">
# <img alt="海市蜃楼" class="" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2551172384.jpg"/>
# </a>
# </dt>
# <dd>
# <a class="" href="https://movie.douban.com/subject/30164448/?from=subject-page">海市蜃楼</a>
# </dd>
# </dl>
# <dl class="">
# <dt>
# <a href="https://movie.douban.com/subject/27615441/?from=subject-page">
# <img alt="网络谜踪" class="" src="https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2542848758.jpg"/>
# </a>
# </dt>
# <dd>
# <a class="" href="https://movie.douban.com/subject/27615441/?from=subject-page">网络谜踪</a>
# </dd>
# </dl>
# </div>
# </div>
# <script id="comment-tmpl" type="text/x-handlebar-tmpl">
#     <div class="dummy-fold">
#         {{#each comments}}
#         <div class="comment-item" data-cid="id">
#             <div class="comment">
#                 <h3>
#                     <span class="comment-vote">
#                             <span class="votes">{{votes}}</span>
#                         <input value="{{id}}" type="hidden"/>
#                         <a href="javascript:;" class="j {{#if ../if_logined}}a_vote_comment{{else}}a_show_login{{/if}}">有用</a>
#                     </span>
#                     <span class="comment-info">
#                         <a href="{{user.path}}" class="">{{user.name}}</a>
#                         {{#if rating}}
#                         <span class="allstar{{rating}}0 rating" title="{{rating_word}}"></span>
#                         {{/if}}
#                         <span>
#                             {{time}}
#                         </span>
#                         <p> {{content_tmpl content}} </p>
#                     </span>
#             </div>
#         </div>
#         {{/each}}
#     </div>
# </script>
# <div id="comments-section">
# <div class="mod-hd">
# <a class="comment_btn j a_show_login" href="https://www.douban.com/register?reason=review" rel="nofollow">
# <span>我要写短评</span>
# </a>
# <h2>
# <i class="">安娜的短评</i>
#               · · · · · ·
#             <span class="pl">
#             (
#                 <a href="https://movie.douban.com/subject/27166976/comments?status=P">全部 17393 条</a>
#             )
#             </span>
# </h2>
# </div>
# <div class="mod-bd">
# <div class="tab-hd">
# <a class="on" data-id="hot" href="comments" id="hot-comments-tab">热门</a> /
#             <a data-id="new" href="comments?sort=time" id="new-comments-tab">最新</a> /
#         <a class="j a_show_login" data-id="following" href="follows_comments" id="following-comments-tab">好友</a>
# </div>
# <div class="tab-bd">
# <div class="tab" id="hot-comments">
# <div class="comment-item" data-cid="1947610509">
# <div class="comment">
# <h3>
# <span class="comment-vote">
# <span class="votes">3660</span>
# <input type="hidden" value="1947610509"/>
# <a class="j a_show_login" href="javascript:;" onclick="">有用</a>
# </span>
# <span class="comment-info">
# <a class="" href="https://www.douban.com/people/128265644/">秀山鲤鱼</a>
# <span>看过</span>
# <span class="allstar40 rating" title="推荐"></span>
# <span class="comment-time " title="2019-09-11 00:41:45">
#                     2019-09-11
#                 </span>
# </span>
# </h3>
# <p class="">
# <span class="short">7分，美国人拍间谍片，苏联人都是傻逼；苏联人拍间谍片，美国人都是傻逼；法国人拍间谍片，美国人和苏联人全是傻逼。</span>
# </p>
# </div>
# </div>
# <div class="comment-item" data-cid="1829728264">
# <div class="comment">
# <h3>
# <span class="comment-vote">
# <span class="votes">601</span>
# <input type="hidden" value="1829728264"/>
# <a class="j a_show_login" href="javascript:;" onclick="">有用</a>
# </span>
# <span class="comment-info">
# <a class="" href="https://www.douban.com/people/roseinthedark/">Nightingale</a>
# <span>看过</span>
# <span class="allstar30 rating" title="还行"></span>
# <span class="comment-time " title="2019-06-21 09:29:40">
#                     2019-06-21
#                 </span>
# </span>
# </h3>
# <p class="">
# <span class="short">生命诚可贵，爱情价更高；若为自由故，两者皆可抛…</span>
# </p>
# </div>
# </div>
# <div class="comment-item" data-cid="1893651054">
# <div class="comment">
# <h3>
# <span class="comment-vote">
# <span class="votes">407</span>
# <input type="hidden" value="1893651054"/>
# <a class="j a_show_login" href="javascript:;" onclick="">有用</a>
# </span>
# <span class="comment-info">
# <a class="" href="https://www.douban.com/people/Tess-A/">邰思</a>
# <span>看过</span>
# <span class="allstar40 rating" title="推荐"></span>
# <span class="comment-time " title="2019-08-06 14:42:58">
#                     2019-08-06
#                 </span>
# </span>
# </h3>
# <p class="">
# <span class="short">同样的KGB背景下，这才是红雀该有的样子——冷漠、美颜、克制，九头身女特工不需要演技爆发，不需要太多情感流露。凯伦米勒和墨菲锤哥还弥补不了演技缺口的话，如何体现女主的弱小无助楚楚可怜又暗地自成一派的刚强呢。该享受美好肉体的时候你在讨论演技，我觉得这在亵渎我的视觉功能。</span>
# </p>
# </div>
# </div>
# <div class="comment-item" data-cid="1875208126">
# <div class="comment">
# <h3>
# <span class="comment-vote">
# <span class="votes">467</span>
# <input type="hidden" value="1875208126"/>
# <a class="j a_show_login" href="javascript:;" onclick="">有用</a>
# </span>
# <span class="comment-info">
# <a class="" href="https://www.douban.com/people/yingmilaola/">影迷劳拉</a>
# <span>看过</span>
# <span class="allstar40 rating" title="推荐"></span>
# <span class="comment-time " title="2019-07-25 21:38:51">
#                     2019-07-25
#                 </span>
# </span>
# </h3>
# <p class="">
# <span class="short">是我向往的感情生活。</span>
# </p>
# </div>
# </div>
# <div class="comment-item" data-cid="1947667418">
# <div class="comment">
# <h3>
# <span class="comment-vote">
# <span class="votes">95</span>
# <input type="hidden" value="1947667418"/>
# <a class="j a_show_login" href="javascript:;" onclick="">有用</a>
# </span>
# <span class="comment-info">
# <a class="" href="https://www.douban.com/people/veverlee/">内陆飞鱼</a>
# <span>看过</span>
# <span class="allstar30 rating" title="还行"></span>
# <span class="comment-time " title="2019-09-11 01:54:37">
#                     2019-09-11
#                 </span>
# </span>
# </h3>
# <p class="">
# <span class="short">虽然是无脑动作片，没有“黑寡妇”主演的《超体》好看。曾经传出米兔新闻的吕克·贝松真的是一生只爱一种女人，波波头，模特身材，少女相貌……这一部女主92年的俄罗斯超模萨沙·露丝，跟年轻时的安娜·帕里约、米拉·乔沃维奇有些像，不知道跟双鱼、直男导演是什么关系。</span>
# </p>
# </div>
# </div>
#
#
#
#
#                 &gt; <a href="comments?sort=new_score&amp;status=P">
#                     更多短评
#                         17393条
#                 </a>
# </div>
# <div class="tab" id="new-comments">
# <div id="normal">
# </div>
# <div class="fold-hd hide">
# <a class="qa" href="/help/opinion#t2-q0" target="_blank">为什么被折叠？</a>
# <a class="btn-unfold" href="#">有一些短评被折叠了</a>
# <div class="qa-tip">
#                     评论被折叠，是因为发布这条评论的帐号行为异常。评论仍可以被展开阅读，对发布人的账号不造成其他影响。如果认为有问题，可以<a href="https://help.douban.com/help/ask?category=movie">联系</a>豆瓣电影。
#                 </div>
# </div>
# <div class="fold-bd">
# </div>
# <span id="total-num"></span>
# </div>
# <div class="tab" id="following-comments">
# <div class="comment-item">
#             你关注的人还没写过短评
#         </div>
# </div>
# </div>
# </div>
# </div>
# <link href="https://img3.doubanio.com/misc/mixed_static/54ebe45c299a020a.css" rel="stylesheet">
# <section class="topics mod">
# <header>
# <h2>
#             安娜的话题 · · · · · ·
#             <span class="pl">( <span class="gallery_topics">全部 <span id="topic-count"></span> 条</span> )</span>
# </h2>
# </header>
# <section class="subject-topics">
# <div class="topic-guide" id="topic-guide">
# <img class="ic_question" src="//img3.doubanio.com/f/ithildin/b1a3edea3d04805f899e9d77c0bfc0d158df10d5/pics/export/icon_question.png">
# <div class="tip_content">
# <div class="tip_title">什么是话题</div>
# <div class="tip_desc">
# <div>无论是一部作品、一个人，还是一件事，都往往可以衍生出许多不同的话题。将这些话题细分出来，分别进行讨论，会有更多收获。</div>
# </div>
# </div>
# <img class="ic_guide" src="//img3.doubanio.com/f/ithildin/529f46d86bc08f55cd0b1843d0492242ebbd22de/pics/export/icon_guide_arrow.png">
# <img class="ic_close" id="topic-guide-close" src="//img3.doubanio.com/f/ithildin/2eb4ad488cb0854644b23f20b6fa312404429589/pics/export/close@3x.png">
# </img></img></img></div>
# <div id="topic-items"></div>
# <script>
#         window.subject_id = 27166976;
#         window.join_label_text = '写影评参与';
#
#         window.topic_display_count = 4;
#         window.topic_item_display_count = 1;
#         window.no_content_fun_call_name = "no_topic";
#
#         window.guideNode = document.getElementById('topic-guide');
#         window.guideNodeClose = document.getElementById('topic-guide-close');
#     </script>
# <link href="https://img3.doubanio.com/f/ithildin/f731c9ea474da58c516290b3a6b1dd1237c07c5e/css/export/subject_topics.css" rel="stylesheet">
# <script src="https://img3.doubanio.com/f/ithildin/d3590fc6ac47b33c804037a1aa7eec49075428c8/js/export/moment-with-locales-only-zh.js"></script>
# <script src="https://img3.doubanio.com/f/ithildin/c600fdbe69e3ffa5a3919c81ae8c8b4140e99a3e/js/export/subject_topics.js"></script>
# </link></section>
# <script>
#         function no_topic(){
#             $('#content .topics').remove();
#         }
#     </script>
# </section>
# <section class="reviews mod movie-content">
# <header>
# <a class="create-review comment_btn " data-isverify="False" data-verify-url="https://www.douban.com/accounts/phone/verify?redir=http://movie.douban.com/subject/27166976/new_review" href="new_review" rel="nofollow">
# <span>我要写影评</span>
# </a>
# <h2>
#             安娜的影评 · · · · · ·
#             <span class="pl">( <a href="reviews">全部 146 条</a> )</span>
# </h2>
# </header>
# <style>
# #gallery-topics-selection {
#   position: fixed;
#   width: 595px;
#   padding: 40px 40px 33px 40px;
#   background: #fff;
#   border-radius: 10px;
#   box-shadow: 0 2px 16px 0 rgba(0, 0, 0, 0.2);
#   top: 50%;
#   left: 50%;
#   -webkit-transform: translate(-50%, -50%);
#   transform: translate(-50%, -50%);
# ...
# </tr>
# <tr>
# <td class="pl"><a href="https://movie.douban.com/subject/27166976/discussion/616447841/" title="电影4分30秒的字幕，请问还有注意到的吗？">电影4分30秒的字幕，请问还有注意到的吗？</a></td>
# <td class="pl"><span>来自</span><a href="https://www.douban.com/people/198617704/">JiGyin</a></td>
# <td class="pl"><span>16 回应</span></td>
# <td class="pl"><span>2019-10-14</span></td>
# </tr>
# <tr>
# <td class="pl"><a href="https://movie.douban.com/subject/27166976/discussion/616426865/" title="想问下女生们都喜欢哪个男主啊？！！">想问下女生们都喜欢哪个男主啊？！！</a></td>
# <td class="pl"><span>来自</span><a href="https://www.douban.com/people/156755294/">Kalia🍉</a></td>
# <td class="pl"><span>79 回应</span></td>
# <td class="pl"><span>2019-10-14</span></td>
# </tr>
# <tr>
# <td class="pl"><a href="https://movie.douban.com/subject/27166976/discussion/616451636/" title="《安娜》同款国际象棋开箱！">《安娜》同款国际象棋开箱！</a></td>
# <td class="pl"><span>来自</span><a href="https://www.douban.com/people/jazzbon/">素人冯</a></td>
# <td class="pl"><span>5 回应</span></td>
# <td class="pl"><span>2019-10-14</span></td>
# </tr>
# <tr>
# <td class="pl"><a href="https://movie.douban.com/subject/27166976/discussion/616432016/" title="哈哈哈哈哈哈墨菲又一次被按倒了">哈哈哈哈哈哈墨菲又一次被按倒了</a></td>
# <td class="pl"><span>来自</span><a href="https://www.douban.com/people/149375281/">Ezra Miller</a></td>
# <td class="pl"><span>1 回应</span></td>
# <td class="pl"><span>2019-10-14</span></td>
# </tr>
# </table>
# <p align="right" class="pl">
# <a href="/subject/27166976/discussion/" rel="nofollow">
#                             &gt; 去这部影片的讨论区（全部145条）
#                         </a>
# </p>
# </div>
# <div id="askmatrix">
# <div class="mod-hd">
# <h2>
#             关于《安娜》的问题
#             · · · · · ·
#             <span class="pl">
#                 (<a href="https://movie.douban.com/subject/27166976/questions/?from=subject">
#                     全部13个
#                 </a>)
#             </span>
# </h2>
# <a class="j a_show_login comment_btn" href="https://movie.douban.com/subject/27166976/questions/ask/?from=subject">我来提问</a>
# </div>
# <div class="mod-bd">
# <ul class="">
# <li class="">
# <span class="tit">
# <a class="" href="https://movie.douban.com/subject/27166976/questions/838800/?from=subject">
#                             1小时24分出现的音乐是什么？
#                     </a>
# </span>
# <span class="meta">
#                     3人回答
#                 </span>
# </li>
# <li class="">
# <span class="tit">
# <a class="" href="https://movie.douban.com/subject/27166976/questions/838919/?from=subject">
#                             大家在哪里看的呀？？
#                     </a>
# </span>
# <span class="meta">
#                     1人回答
#                 </span>
# </li>
# </ul>
# <p>&gt;
#             <a href="https://movie.douban.com/subject/27166976/questions/?from=subject">
#                 全部13个问题
#             </a>
# </p>
# </div>
# </div>
# <script type="text/javascript">
#         $(function(){if($.browser.msie && $.browser.version == 6.0){
#             var $info = $('#info'),
#                 maxWidth = parseInt($info.css('max-width'));
#             if($info.width() > maxWidth) {
#                 $info.width(maxWidth);
#             }
#         }});
#     </script>
# </link></link></div>
# <div class="aside">
# <!-- douban ad begin -->
# <div id="dale_movie_subject_top_right"></div>
# <div id="dale_movie_subject_top_middle"></div>
# <!-- douban ad end -->
# <style type="text/css">
#     .m4 {margin-bottom:8px; padding-bottom:8px;}
#     .movieOnline {background:#FFF6ED; padding:10px; margin-bottom:20px;}
#     .movieOnline h2 {margin:0 0 5px;}
#     .movieOnline .sitename {line-height:2em; width:160px;}
#     .movieOnline td,.movieOnline td a:link,.movieOnline td a:visited{color:#666;}
#     .movieOnline td a:hover {color:#fff;}
#     .link-bt:link,
#     .link-bt:visited,
#     .link-bt:hover,
#     .link-bt:active {margin:5px 0 0; padding:2px 8px; background:#a8c598; color:#fff; -moz-border-radius: 3px; -webkit-border-radius: 3px; border-radius: 3px; display:inline-block;}
# </style>
# <div class="tags">
# <h2>
# <i class="">豆瓣成员常用的标签</i>
#               · · · · · ·
#     </h2>
# <div class="tags-body">
# <a class="" href="/tag/吕克·贝松">吕克·贝松</a>
# <a class="" href="/tag/动作">动作</a>
# <a class="" href="/tag/特工">特工</a>
# <a class="" href="/tag/法国">法国</a>
# <a class="" href="/tag/悬疑">悬疑</a>
# <a class="" href="/tag/2019">2019</a>
# <a class="" href="/tag/电影">电影</a>
# <a class="" href="/tag/惊悚">惊悚</a>
# </div>
# </div>
# <div id="dale_movie_review_right_guess_you_like"></div>
# <div id="dale_movie_subject_inner_middle"></div>
# <div id="dale_movie_subject_download_middle"></div>
# <div id="subject-doulist">
# <h2>
# <i class="">以下豆列推荐</i>
#               · · · · · ·
#             <span class="pl">
#             (
#                 <a href="https://movie.douban.com/subject/27166976/doulists">全部</a>
#             )
#             </span>
# </h2>
# <ul>
# <li>
# <a href="https://www.douban.com/doulist/30299/" target="_blank">豆瓣电影【口碑榜】2019-10-12 更新</a>
# <span>(影志)</span>
# </li>
# <li>
# <a href="https://www.douban.com/doulist/43280105/" target="_blank">生命的演绎。</a>
# <span>(刺青童)</span>
# </li>
# <li>
# <a href="https://www.douban.com/doulist/44585567/" target="_blank">严重收藏癖患者的网盘资源清单，病友进！！</a>
# <span>(秀山鲤鱼)</span>
# </li>
# <li>
# <a href="https://www.douban.com/doulist/1593367/" target="_blank">2019—2021值得期待的影片（欧洲日韩）</a>
# <span>(closer)</span>
# </li>
# <li>
# <a href="https://www.douban.com/doulist/1385420/" target="_blank">临幸后宫之影视大类</a>
# <span>(nikki)</span>
# </li>
# </ul>
# </div>
# <div id="subject-others-interests">
# <h2>
# <i class="">谁在看这部电影</i>
#               · · · · · ·
#     </h2>
# <ul class="">
# <li class="">
# <a class="others-interest-avatar" href="https://www.douban.com/people/150537557/">
# <img alt="袁信力" class="pil" src="https://img3.doubanio.com/icon/u150537557-1.jpg">
# </img></a>
# <div class="others-interest-info">
# <a class="" href="https://www.douban.com/people/150537557/">袁信力</a>
# <div class="">
#                         刚刚
#                         看过
#                         <span class="allstar40" title="推荐"></span>
# </div>
# </div>
# </li>
# <li class="">
# <a class="others-interest-avatar" href="https://www.douban.com/people/54767000/">
# <img alt="天山雪莲" class="pil" src="https://img3.doubanio.com/icon/u54767000-125.jpg">
# </img></a>
# <div class="others-interest-info">
# <a class="" href="https://www.douban.com/people/54767000/">天山雪莲</a>
# <div class="">
#                         刚刚
#                         看过
#                         <span class="allstar40" title="推荐"></span>
# </div>
# </div>
# </li>
# <li class="">
# <a class="others-interest-avatar" href="https://www.douban.com/people/4551464/">
# <img alt="纸马" class="pil" src="https://img3.doubanio.com/icon/u4551464-10.jpg">
# </img></a>
# <div class="others-interest-info">
# <a class="" href="https://www.douban.com/people/4551464/">纸马</a>
# <div class="">
#                         1分钟前
#                         想看
#
#                     </div>
# </div>
# </li>
# </ul>
# <div class="subject-others-interests-ft">
# <a href="https://movie.douban.com/subject/27166976/collections">63071人看过</a>
#                  /
#             <a href="https://movie.douban.com/subject/27166976/wishes">43322人想看</a>
# </div>
# </div>
# <!-- douban ad begin -->
# <div id="dale_movie_subject_middle_right"></div>
# <script type="text/javascript">
#     (function (global) {
#         if(!document.getElementsByClassName) {
#             document.getElementsByClassName = function(className) {
#                 return this.querySelectorAll("." + className);
#             };
#             Element.prototype.getElementsByClassName = document.getElementsByClassName;
#
#         }
#         var articles = global.document.getElementsByClassName('article'),
#             asides = global.document.getElementsByClassName('aside');
#
#         if (articles.length > 0 && asides.length > 0 && articles[0].offsetHeight >= asides[0].offsetHeight) {
#             (global.DoubanAdSlots = global.DoubanAdSlots || []).push('dale_movie_subject_middle_right');
#         }
#     })(this);
# </script>
# <!-- douban ad end -->
# <br/>
# <p class="pl">订阅安娜的评论: <br/><span class="feed">
# <a href="https://movie.douban.com/feed/subject/27166976/reviews"> feed: rss 2.0</a></span></p>
# </div>
# <div class="extra">
# <!-- douban ad begin -->
# <div id="dale_movie_subject_bottom_super_banner"></div>
# <script type="text/javascript">
#     (function (global) {
#         var body = global.document.body,
#             html = global.document.documentElement;
#
#         var height = Math.max(body.scrollHeight, body.offsetHeight, html.clientHeight, html.scrollHeight, html.offsetHeight);
#         if (height >= 2000) {
#             (global.DoubanAdSlots = global.DoubanAdSlots || []).push('dale_movie_subject_bottom_super_banner');
#         }
#     })(this);
# </script>
# <!-- douban ad end -->
# </div>
# </div>
# </div>
# <div id="footer">
# <div class="footer-extra"></div>
# <span class="fleft gray-link" id="icp">
#     © 2005－2019 douban.com, all rights reserved 北京豆网科技有限公司
# </span>
# <a href="https://www.douban.com/hnypt/variformcyst.py" style="display: none;"></a>
# <span class="fright">
# <a href="https://www.douban.com/about">关于豆瓣</a>
#     · <a href="https://www.douban.com/jobs">在豆瓣工作</a>
#     · <a href="https://www.douban.com/about?topic=contactus">联系我们</a>
#     · <a href="https://www.douban.com/about/legal">法律声明</a>
#
#     · <a href="https://help.douban.com/?app=movie" target="_blank">帮助中心</a>
#     · <a href="https://www.douban.com/doubanapp/">移动应用</a>
#     · <a href="https://www.douban.com/partner/">豆瓣广告</a>
# </span>
# </div>
# </div>
# <script src="https://img3.doubanio.com/misc/mixed_static/4d16b026f992ff64.js" type="text/javascript"></script>
# <link href="https://img3.doubanio.com/f/shire/8377b9498330a2e6f056d863987cc7a37eb4d486/css/ui/dialog.css" rel="stylesheet" type="text/css"/>
# <link href="https://img3.doubanio.com/f/movie/4aca95d66d37ec0712b3d19973b5d8feb75f2f05/css/movie/mod/reg_login_pop.css" rel="stylesheet" type="text/css"/>
# <script data-cfg-autoload="false" src="https://img3.doubanio.com/f/shire/77323ae72a612bba8b65f845491513ff3329b1bb/js/do.js" type="text/javascript"></script>
# <script src="https://img3.doubanio.com/f/shire/383a6e43f2108dc69e3ff2681bc4dc6c72a5ffb0/js/ui/dialog.js" type="text/javascript"></script>
# <script type="text/javascript">
#         var HTTPS_DB='https://www.douban.com';
# var account_pop={open:function(o,e){e?referrer="?referrer="+encodeURIComponent(e):referrer="?referrer="+window.location.href;var n="",i="",t=448;n="用户登录",i="https://accounts.douban.com/passport/login_popup?source=movie";var r=document.location.protocol+"//"+document.location.hostname,a=dui.Dialog({width:340,title:n,height:t,cls:"account_pop",isHideTitle:!0,modal:!0,content:"<iframe scrolling='no' frameborder='0' width='340' height='"+t+"' src='"+i+"' name='"+r+"'></iframe>"},!0),c=a.node;if(c.undelegate(),c.delegate(".dui-dialog-close","click",function(){var o=$("body");o.find("#login_msk").hide(),o.find(".account_pop").remove()}),$(window).width()<478){var d="";"reg"===o?d=HTTPS_DB+"/accounts/register"+referrer:"login"===o&&(d=HTTPS_DB+"/accounts/login"+referrer),window.location.href=d}else a.open();$(window).bind("message",function(o){"https://accounts.douban.com"===o.originalEvent.origin&&(c.find("iframe").css("height",o.originalEvent.data),c.height(o.originalEvent.data),a.update())})}};Douban&&Douban.init_show_login&&(Douban.init_show_login=function(o){var e=$(o);e.click(function(){var o=e.data("ref")||"";return account_pop.open("login",o),!1})}),Do(function(){$("body").delegate(".pop_register","click",function(o){o.preventDefault();var e=$(this).data("ref")||"";return account_pop.open("reg",e),!1}),$("body").delegate(".pop_login","click",function(o){o.preventDefault();var e=$(this).data("ref")||"";return account_pop.open("login",e),!1})});
#     </script>
# <script type="text/javascript">
#     (function (global) {
#         var newNode = global.document.createElement('script'),
#             existingNode = global.document.getElementsByTagName('script')[0],
#             adSource = '//erebor.douban.com/',
#             userId = '',
#             browserId = '_ibNUmVsOMo',
#             criteria = '7:詹姆斯·乔因特|7:艾莉森·惠勒|7:动作|7:惊悚|7:伊凡·弗拉内克|7:法国电影|7:安德鲁·霍华德|7:艾力克·高敦|7:亚历山大·佩特罗夫|7:让·巴蒂斯特·普奇|7:谢尔盖·巴切乌尔斯基|7:特工|7:2019|7:詹·奥利弗·施罗德|7:基里安·墨菲|7:限制级|7:吕克·贝松|7:阿德里安·坎恩|7:悬疑|7:海伦·米伦|7:卢克·伊万斯|7:阿列克谢·马斯洛杜多夫|7:尼基塔·帕夫连科|7:莱拉·阿波瓦|7:电影|7:法国|7:萨莎·露丝|7:雷吉尔·库迪乌|7:安娜·克里帕|7:耶斯·利奥丹|3:/subject/27166976/',
#             preview = '',
#             debug = false,
#             adSlots = ['dale_movie_subject_top_icon', 'dale_movie_subject_top_right', 'dale_movie_subject_top_middle', 'dale_movie_subject_inner_middle', 'dale_movie_subject_download_middle', 'dale_movie_review_right_guess_you_like'];
#
#         global.DoubanAdRequest = {src: adSource, uid: userId, bid: browserId, crtr: criteria, prv: preview, debug: debug};
#         global.DoubanAdSlots = (global.DoubanAdSlots || []).concat(adSlots);
#
#         newNode.setAttribute('type', 'text/javascript');
#         newNode.setAttribute('src', '//img1.doubanio.com/dDY0Zjl6NS9mL2FkanMvNGQ1MjFiYTY2ZGE0MjE4OTc4YmYyOWZhODVjZDA2ZDdmODAyMTlkMy9hZC5yZWxlYXNlLmpz');
#         newNode.setAttribute('async', true);
#         existingNode.parentNode.insertBefore(newNode, existingNode);
#     })(this);
# </script>
# <script type="text/javascript">
# var _paq = _paq || [];
# _paq.push(['trackPageView']);
# _paq.push(['enableLinkTracking']);
# (function() {
#     var p=(('https:' == document.location.protocol) ? 'https' : 'http'), u=p+'://fundin.douban.com/';
#     _paq.push(['setTrackerUrl', u+'piwik']);
#     _paq.push(['setSiteId', '100001']);
#     var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
#     g.type='text/javascript';
#     g.defer=true;
#     g.async=true;
#     g.src=p+'://img3.doubanio.com/dae/fundin/piwik.js';
#     s.parentNode.insertBefore(g,s);
# })();
# </script>
# <script type="text/javascript">
# var setMethodWithNs = function(namespace) {
#   var ns = namespace ? namespace + '.' : ''
#     , fn = function(string) {
#         if(!ns) {return string}
#         return ns + string
#       }
#   return fn
# }
#
# var gaWithNamespace = function(fn, namespace) {
#   var method = setMethodWithNs(namespace)
#   fn.call(this, method)
# }
#
# var _gaq = _gaq || []
#   , accounts = [
#       { id: 'UA-7019765-1', namespace: 'douban' }
#     , { id: 'UA-7019765-19', namespace: '' }
#     ]
#   , gaInit = function(account) {
#       gaWithNamespace(function(method) {
#         gaInitFn.call(this, method, account)
#       }, account.namespace)
#     }
#   , gaInitFn = function(method, account) {
#       _gaq.push([method('_setAccount'), account.id]);
#       _gaq.push([method('_setSampleRate'), '5']);
#
#
#   _gaq.push([method('_addOrganic'), 'google', 'q'])
#   _gaq.push([method('_addOrganic'), 'baidu', 'wd'])
#   _gaq.push([method('_addOrganic'), 'soso', 'w'])
#   _gaq.push([method('_addOrganic'), 'youdao', 'q'])
#   _gaq.push([method('_addOrganic'), 'so.360.cn', 'q'])
#   _gaq.push([method('_addOrganic'), 'sogou', 'query'])
#   if (account.namespace) {
#     _gaq.push([method('_addIgnoredOrganic'), '豆瓣'])
#     _gaq.push([method('_addIgnoredOrganic'), 'douban'])
#     _gaq.push([method('_addIgnoredOrganic'), '豆瓣网'])
#     _gaq.push([method('_addIgnoredOrganic'), 'www.douban.com'])
#   }
#
#       if (account.namespace === 'douban') {
#         _gaq.push([method('_setDomainName'), '.douban.com'])
#       }
#
#         _gaq.push([method('_setCustomVar'), 1, 'responsive_view_mode', 'desktop', 3])
#
#         _gaq.push([method('_setCustomVar'), 2, 'login_status', '0', 2]);
#
#       _gaq.push([method('_trackPageview')])
#     }
#
# for(var i = 0, l = accounts.length; i < l; i++) {
#   var account = accounts[i]
#   gaInit(account)
# }
#
#
# ;(function() {
#     var ga = document.createElement('script');
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     ga.setAttribute('async', 'true');
#     document.documentElement.firstChild.appendChild(ga);
# })()
# </script>
# <!-- belba4-docker-->
# <script>_SPLITTEST=''</script>
# </link></link></body>
# </html>
#
# 安娜 (豆瓣)
# director : 吕克·贝松
# actor : 萨莎·露丝,海伦·米伦,卢克·伊万斯,基里安·墨菲,莱拉·阿波瓦,亚历山大·佩特罗夫
# 故事聚焦神秘女杀手安娜的成长及执行各种暗杀任务的经历，在美丽的外表下，安娜拥有聪明绝顶的头脑和强大的战斗技巧，是世界上最恐怖的刺客之一，她游走于黑白两道，只要被锁定的目标，从不失手。
# description : 故事聚焦神秘女杀手安娜的成长及执行各种暗杀任务的经历，在美丽的外表下，安娜拥有聪明绝顶的头脑和强大的战斗技巧，是世界上最恐怖的刺客之一，她游走于黑白两道，只要被锁定的目标，从不失手。
# aggregateRating : 7.7

# %% [markdown]
# ## test search_text

# %%
# -*- coding: utf-8 -*-
 
import urllib,re,json
 
#movie:
     #search engine:http://movie.douban.com/subject_search?search_text=+film_name+&cat=1002
     #info:https://api.douban.com/v2/movie/:id
 
print("please input the name of film u want to search:")
# film_name = raw_input()
film_name = u'天下无贼'.encode("utf-8")
movie_search_engine = "http://movie.douban.com/subject_search?search_text="+film_name+"&cat=1002"
print "film_name:%s"%(film_name)
movie_search = movie_search_engine
html = urllib.urlopen(movie_search).read()
match = re.findall('<a class="nbg" href="(.+?)" >',html)
# print html
match = match[0]
movie_id = re.split(r'\D+',match)
movie_id = movie_id[1]
movie_url = "https://api.douban.com/v2/movie/"+movie_id
movie_url = urllib.urlopen(movie_url).read()
jsondata = json.loads(movie_url)
name = jsondata["alt_title"]
rate = jsondata["rating"]["average"]
director = jsondata["attrs"]["director"][0]
cast = jsondata["attrs"]["cast"]
pubdate = jsondata["attrs"]["pubdate"][0]
movie_duration = jsondata["attrs"]["movie_duration"][0]
country = jsondata["attrs"]["country"][0]
movie_type = jsondata["attrs"]["movie_type"]
print("name:" + name)
print("rate:" + rate)
print("director:" + director)
print("casts:" + cast[0] +"\\"+ cast[1] +"\\"+ cast[2])
print("country:" + country)
print("duration:" + movie_duration)
print("pubdate:" + pubdate)
print("country:" + movie_type[0] +"\\"+ movie_type[1] +"\\"+ movie_type[2])
print("--------------------------------------------------------By Douban")
# Out:
# please input the name of film u want to search:
# film_name:天下无贼
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-fb6a742aa2f5> in <module>()
#      16 match = re.findall('<a class="nbg" href="(.+?)" >',html)
#      17 # print html
# ---> 18 match = match[0]
#      19 movie_id = re.split(r'\D+',match)
#      20 movie_id = movie_id[1]
#
# IndexError: list index out of range

# %% [markdown]
# ## Error Search

# %%
try:
    from urllib.request import urlopen, Request
except ImportError:
    from urllib2 import urlopen, Request
import requests
import ssl
import json

def ajaxCrawler(url):
    headers = {
        "User-Agent":"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Maxthon/4.4.3.4000 Chrome/30.0.1599.101 Safari/537.36"
    }
    req = Request(url, headers=headers)

    # 使用ssl创建未验证的上下文
    context = ssl._create_unverified_context()


    response = urlopen(req,context=context)

    jsonStr = response.read().decode("utf-8")
#     jsonData = json.loads(jsonStr)
    return jsonStr

# url = "https://movie.douban.com/j/chart/top_list?type=11&interval_id=100%3A90&action=&start=0&limit=20"
url = 'https://movie.douban.com/subject_search?search_text=%E5%8A%9F%E5%A4%AB%E4%B9%8B%E7%8E%8B'
info = ajaxCrawler(url)
# print(info)
# --------------------- 
# 作者：aspiring123 
# 来源：CSDN 
# 原文：https://blog.csdn.net/qq_39198486/article/details/81503383 
# 版权声明：本文为博主原创文章，转载请附上博文链接！
