# %%
# -*- coding:utf-8 -*-
import os
import requests
headers = {
   'User-Agent': "Mozilla/5.0 (Windows NT 6.1; Win64; x64) "
                 "AppleWebKit/537.36 (KHTML, like Gecko) "
                 "Chrome/72.0.3626.109 Safari/537.36",
}

def get_url_content(url):
   '''获取m3u8文件的内容并放入内存'''
#    m3u8_target = input('输入m3u8对应URL:').strip()
   m3u8_target = url.strip()
   target = '/'.join(m3u8_target.split('/')[:-1])
   # print(target)
   m3u8_res = requests.get(m3u8_target,headers)
   if m3u8_res.status_code != 200:
      print('URL不能正常访问:%s'%(m3u8_res.status_code))
   m3u8_content = m3u8_res.content.decode('utf8')
   return m3u8_content,target


def read_m3u8(m3u8_content):
   '''获取m3u8中的下载连接'''
   media_url_list = []
   lines_list = m3u8_content.strip().split('\r\n')
   if len(lines_list) < 3:
      lines_list = m3u8_content.strip().split('\n')
   if '#EXTM3U' not in m3u8_content:
      raise BaseException('非M3U8连接')
   for index,line in enumerate(lines_list):
      # print(index,line)
      if '#EXTINF' in line:
         media_url_list.append(lines_list[index+1])
   return media_url_list

import sys
def download_media(url_list,target,dir_path):
    '''下载媒体文件'''
    f_name = url_list[-2].split('_')[0]+'.mp4'
    media_file_path = dir_path +f_name
    print "f_name:%s"%(media_file_path)
    is_exists = os.path.exists(media_file_path)
    if is_exists:
        print "file exist:%s "%(media_file_path)
    else:
        for index,url in enumerate(url_list):
            try:
                res = requests.get(url,headers)
            except requests.exceptions.MissingSchema:  #捕获不完整URL的异常
                target_url =target+'/'+url
                res = requests.get(target_url,headers)
            #       media_file_path = dir_path+'full_media.mp4'
            #       media_file_path = dir_path+f_name+'.mp4'
            except Exception as e:
                print index,url
            if res.status_code != 200:
                print('下载URL连接访问失败')
                break
            with open(media_file_path,'ab')as f:
                f.write(res.content) 
            print('%.1f%%' % (((index + 1) / float(len(url_list))) * 100)),
        flag = False
        if index == len(url_list) - 1:
            flag = True
        return flag


# def main():
# #    file_name = raw_input("输入媒体名称:")
#    file_name = 'feicheng'
#    dir_path = mkdir(file_name)       #创建媒体名命名的文件夹
#    m3u8_content,target = get_url_content(URL)
#    media_url_list = read_m3u8(m3u8_content)
#    print media_url_list[-2]
#    flag = download_media(media_url_list,target, dir_path,file_name) #  用于校验是否成功下载媒体文件
#    if flag:
#       print('媒体下载完成')
#    else:
#       print('媒体下载失败')
#    print("*"*16)
def mkdir(path):
   path = path.strip().rstrip('\\')
   print path
   is_exists = os.path.exists(path)
   if not is_exists:      # 校验目录是否存在
      os.makedirs(path)
      print('创建媒体目录')
   else:
      print('媒体目录已经存在')
   return path+'/'
if __name__ == '__main__':
#    print('''
#    使用方法：
#    推荐全网视频解析api：https://jqaaa.com/jx.php?url=
#    抓包获取m3u8的URL地址后复制使用
#    ''')

    URL = 'http://qvw.mvaas.cn/hls/2f03f5b30ec2f83c2f85/3nsiji1ebq5ix4d5z694/n_n/34c67d2c3577a9dbd3ae10fd0986d1ec.m3u8?xstToken=7370b86c'
    #    URL ='http://qvw.mvaas.cn/hls/2f03f5b30ec2f83c2f85/jk96mnx3pq6yvgh82quf/n_n/7df3e9722c524081410ab5d43d4c1d59.m3u8?xstToken=5969e397'
    #第一夫人vdo:809M Apr 25  2019 95bfd13b4b8d92bcd80c98323a5302dc/95bfd13b4b8d92bcd80c98323a5302dc.vdo
#     URL ='http://qvw.mvaas.cn/hls/2f03f5b30ec2f83c2f85/7q6bmtjfdwwed45wbs64/720_25_4_1000k_4_7_n/95bfd13b4b8d92bcd80c98323a5302dc.m3u8?xstToken=cee16c0a'
#     URL ='http://fcqvw.mvaas.cn/hls/2f03f5b30ec2f83c2f85/7q6bmtjfdwwed45wbs64/n_n/4f4424fa61e801708ac679173bb41574.m3u8?xstToken=cee16c0a'
    URL ='http://qvw.mvaas.cn/hls/2f03f5b30ec2f83c2f85/7q6bmtjfdwwed45wbs64/n_n/4f4424fa61e801708ac679173bb41574.m3u8?xstToken=cee16c0a'
    
    #    while True:
    #    main()
    file_name = 'feicheng'
    dir_path = mkdir(file_name)       #创建媒体名命名的文件夹
    m3u8_content,target = get_url_content(URL)
    media_url_list = read_m3u8(m3u8_content)
    print media_url_list[-2]
    flag = download_media(media_url_list,target, dir_path) #  用于校验是否成功下载媒体文件
    if flag:
      print('媒体下载完成')
    else:
      print('媒体下载失败')
    print("*"*16)
# Out:
#  feicheng
# 媒体目录已经存在
# a1fc3809b24b4267b3e21ca0fdcd4496_0001996.ts
# f_name:feicheng/a1fc3809b24b4267b3e21ca0fdcd4496.mp4
# ...

# %%
def download_media(url_list,target,dir_path):
    '''下载媒体文件'''
    f_name = url_list[-2].split('_')[0]+'.mp4'
    media_file_path = dir_path +f_name
    print "f_name:%s"%(media_file_path)
    is_exists = os.path.exists(media_file_path)
    if is_exists:
        print "file exist:%s "%(media_file_path)
    else:
        for index,url in enumerate(url_list):
            try:
                print index,url
                res = requests.get(url,headers)
            except requests.exceptions.MissingSchema:  #捕获不完整URL的异常
                target_url =target+'/'+url
                res = requests.get(target_url,headers)
            #       media_file_path = dir_path+'full_media.mp4'
            #       media_file_path = dir_path+f_name+'.mp4'
            if res.status_code != 200:
                print('下载URL连接访问失败')
                break
            with open(media_file_path,'ab')as f:
                f.write(res.content)
            print('下载进度：%.1f%%' % (((index + 1) / len(url_list)) * 100))
            flag = False
            if index == len(url_list) - 1:
                flag = True
            return flag
